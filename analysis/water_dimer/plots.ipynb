# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
grace_off_2l_medium = pd.read_csv("output/energies_grace_b_off_2l_medium.csv")
grace_off_2l_small = pd.read_csv("output/energies_grace_b_off_2l_small.csv")
grace_off_1l_medium = pd.read_csv("output/energies_grace_b_off_1l_medium.csv")
grace_off_1l_small = pd.read_csv("output/energies_grace_b_off_1l_small.csv")

grace_off_2l_medium_wps = pd.read_csv("output/energies_grace_a_wpS_2l_medium.csv")
grace_off_2l_small_wps = pd.read_csv("output/energies_grace_a_wpS_2l_small.csv")
grace_off_1l_medium_wps = pd.read_csv("output/energies_grace_a_wpS_1l_medium.csv")
grace_off_1l_small_wps = pd.read_csv("output/energies_grace_a_wpS_1l_small.csv")

mace_small = pd.read_csv("output/energies_mace_small.csv")
mace_medium = pd.read_csv("output/energies_mace_medium.csv")
mace_large = pd.read_csv("output/energies_mace_large.csv")

dft1 = pd.read_csv("enedat_dft1red.dat", delimiter=' ')

# %%
dist_dft=dft1.iloc[:,0]
energy_dft=dft1.iloc[:,1]

# %%
grace_off_1l_small['energy_kJ_per_mol'][-2:-1]
# Out:
# 149   -20.087737
# Name: energy_kJ_per_mol, dtype: float64

# %%
start = 40
end = 100
eV_to_kjmol = 1.602176634e-19 * 6.02214076e23 / 1000
eV_to_kcalmol = eV_to_kjmol / 4.184

plt.plot(grace_off_1l_small['distance'][start:end]+2.752, (grace_off_1l_small['energy_kJ_per_mol'][start:end]-grace_off_1l_small['energy_kJ_per_mol'][-2:-1].values)*eV_to_kcalmol, label='grace_off_1l_small')
plt.plot(grace_off_1l_medium['distance'][start:end]+2.752, (grace_off_1l_medium['energy_kJ_per_mol'][start:end]-grace_off_1l_medium['energy_kJ_per_mol'][-2:-1].values)*eV_to_kcalmol, label='grace_off_1l_small')
plt.plot(grace_off_2l_small['distance'][start:end]+2.752, (grace_off_2l_small['energy_kJ_per_mol'][start:end]-grace_off_2l_small['energy_kJ_per_mol'][-2:-1].values)*eV_to_kcalmol, label='grace_off_2l_small')
plt.plot(grace_off_2l_medium['distance'][start:end]+2.752, (grace_off_2l_medium['energy_kJ_per_mol'][start:end]-grace_off_2l_medium['energy_kJ_per_mol'][-2:-1].values)*eV_to_kcalmol, label='grace_off_2l_small')

plt.plot(grace_off_1l_small_wps['distance'][start:end]+2.752, (grace_off_1l_small_wps['energy_kJ_per_mol'][start:end]-grace_off_1l_small_wps['energy_kJ_per_mol'][-2:-1].values)*eV_to_kcalmol, label='grace_off_1l_small_wps')
plt.plot(grace_off_1l_medium_wps['distance'][start:end]+2.752, (grace_off_1l_medium_wps['energy_kJ_per_mol'][start:end]-grace_off_1l_medium_wps['energy_kJ_per_mol'][-2:-1].values)*eV_to_kcalmol, label='grace_off_1l_medium_wps')
plt.plot(grace_off_2l_small_wps['distance'][start:end]+2.752, (grace_off_2l_small_wps['energy_kJ_per_mol'][start:end]-grace_off_2l_small_wps['energy_kJ_per_mol'][-2:-1].values)*eV_to_kcalmol, label='grace_off_2l_small_wps')
plt.plot(grace_off_2l_medium_wps['distance'][start:end]+2.752, (grace_off_2l_medium_wps['energy_kJ_per_mol'][start:end]-grace_off_2l_medium_wps['energy_kJ_per_mol'][-2:-1].values)*eV_to_kcalmol, label='grace_off_2l_medium_wps')

plt.plot(mace_small['distance'][start:end]+2.752, (mace_small['energy_kJ_per_mol'][start:end]-mace_small['energy_kJ_per_mol'][-2:-1].values)*eV_to_kcalmol, label='mace_small23')
plt.plot(mace_medium['distance'][start:end]+2.752, (mace_medium['energy_kJ_per_mol'][start:end]-mace_medium['energy_kJ_per_mol'][-2:-1].values)*eV_to_kcalmol, label='mace_medium24')
plt.plot(mace_large['distance'][start:end]+2.752, (mace_large['energy_kJ_per_mol'][start:end]-mace_large['energy_kJ_per_mol'][-2:-1].values)*eV_to_kcalmol, label='mace_large23')

plt.axvline(x=4.5, color='gray', linestyle='--', linewidth=1)
plt.axvline(x=5, color='gray', linestyle='--', linewidth=1)
plt.axvline(x=6, color='gray', linestyle='--', linewidth=1)

plt.axhline(y=0, linestyle='dashed', color='gray')


plt.legend()

# %%
start = 0
plt.plot(grace_off_2l_medium['distance'][start:], grace_off_2l_medium['energy_kJ_per_mol'][start:])

# %%
import numpy as np
print(dist_dft[np.argmin(energy_dft)+1])
# Out:
# 2.95270851

# %%
np.argmin(mace_small['energy_kJ_per_mol'])
# Out:
# 13

# %%
mace_small['distance'][13]
# Out:
# -3.8
